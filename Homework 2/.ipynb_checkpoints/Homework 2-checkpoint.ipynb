# %% [markdown]
# # Homework 2
# ### Predicting Housing Prices

# %%
# Let's import necessary packages
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from scipy import stats
#import packages for modeling
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn import ensemble, tree, linear_model
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, ElasticNetCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.kernel_ridge import KernelRidge
#from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, train_test_split, learning_curve
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline, make_pipeline

#Silence warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Read in the data
train = pd.read_csv(r"C:\Users\Cole\Documents\Machine Learning\Homework 2\train.csv")
test = pd.read_csv(r"C:\Users\Cole\Documents\Machine Learning\Homework 2\test.csv")

# %%
print(train.shape,test.shape)
# Out:
# (1460, 81) (1459, 80)

# %%
#Let's take a look at the data and see what we've got here
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Let's get an idea for the values we have in each column
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
#Let's see the column headers and data types
pd.set_option('display.max_rows', 85)
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
#For utilities, all the values are pretty much the same, so it won't affect our model much
#Also, please note that I will be performing the same data cleaning on the test set, as well as the train set
train = train.drop(['Utilities'], axis=1)
test = test.drop(['Utilities'], axis=1)
print(train.shape,test.shape)
# Out:
# (1460, 80) (1459, 79)

# %% [markdown]
# ### Outliers

# %%
#Let's look at SalePrice and GrLivArea (Above ground living area sqft)
graph = pd.concat([train['SalePrice'], train['GrLivArea']], axis=1)
graph.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0,800000));

# %% [markdown]
# Looks like there's two big outliers where large homes were sold for very cheap. Let's drop those.

# %%
#Dropping 2 Outliers
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

# %% [markdown]
# ### Target Variable

# %%
#Let's take a look at our target variable, SalePrice
sns.distplot(train['SalePrice'], fit=stats.norm);

# %%
#Hmm doesn't look very normal, so let's do a log transformation to normalize SalePrice
train.SalePrice = np.log1p(train.SalePrice)
sns.distplot(train.SalePrice)

# %% [markdown]
# That looks a lot better!

# %% [markdown]
# ### Missing Data

# %%
#Check for missing data (how many missing observations, out of 1460)
pd.concat([train.isnull().sum().sort_values(ascending=False),(train.isnull().sum()*100/train.isnull().count()).sort_values(ascending=False)],axis=1,keys=['Total','Percentage'])
# Out:
#                Total  Percentage
# PoolQC          1452   99.588477
# MiscFeature     1404   96.296296
# Alley           1367   93.758573
# Fence           1177   80.727023
# FireplaceQu      690   47.325103
# LotFrontage      259   17.764060
# GarageType        81    5.555556
# GarageFinish      81    5.555556
# GarageQual        81    5.555556
# GarageCond        81    5.555556
# GarageYrBlt       81    5.555556
# BsmtFinType2      38    2.606310
# BsmtExposure      38    2.606310
# BsmtQual          37    2.537723
# BsmtCond          37    2.537723
# BsmtFinType1      37    2.537723
# MasVnrArea         8    0.548697
# MasVnrType         8    0.548697
# Electrical         1    0.068587
# RoofMatl           0    0.000000
# Exterior1st        0    0.000000
# RoofStyle          0    0.000000
# ExterQual          0    0.000000
# Exterior2nd        0    0.000000
# YearBuilt          0    0.000000
# ExterCond          0    0.000000
# Foundation         0    0.000000
# ...

# %% [markdown]
# It seems that four of our columns are missing over 80% of their data. However, after looking at the variable descriptions, it turns out that most of these aren't actually missing data. If the house doesn't have a pool, then Pool Quality will be left empty. SO for many of the 'missing data' we need to fill them with 'none.'

# %%
#Filling in 'None' where we're missing categorial data, because the feature doesn't exist at that specific property
for col in ( 'PoolQC','MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', "MasVnrType", 'MSSubClass'):
    train[col]=train[col].fillna('None')
    test[col]=test[col].fillna('None')
print(train.shape,test.shape)
# Out:
# (1458, 80) (1459, 79)

# %%
#Similarly, there are variables where missing data means 0, so let's fill those
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'MasVnrArea', 'GarageCars',
               'GarageArea', 'GarageYrBlt'):
    train[col]=train[col].fillna(0)
    test[col]=test[col].fillna(0)
    
print(train.shape,test.shape)
# Out:
# (1458, 80) (1459, 79)

# %%
#We can use the median LotFrontage for each respective neighborhood to fill in missing values for LotFrontage
train["LotFrontage"] = train.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
test["LotFrontage"] = test.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
print(train.shape,test.shape)
# Out:
# (1458, 80) (1459, 79)

# %%
#Let's check and see what missing data is left
pd.concat([train.isnull().sum().sort_values(ascending=False),(train.isnull().sum()*100/train.isnull().count()).sort_values(ascending=False)],axis=1,keys=['Total','Percentage'])
# Out:
#                Total  Percentage
# Electrical         1    0.068587
# SalePrice          0    0.000000
# Foundation         0    0.000000
# RoofMatl           0    0.000000
# Exterior1st        0    0.000000
# Exterior2nd        0    0.000000
# MasVnrType         0    0.000000
# MasVnrArea         0    0.000000
# ExterQual          0    0.000000
# ExterCond          0    0.000000
# BsmtQual           0    0.000000
# Heating            0    0.000000
# BsmtCond           0    0.000000
# BsmtExposure       0    0.000000
# BsmtFinType1       0    0.000000
# BsmtFinSF1         0    0.000000
# BsmtFinType2       0    0.000000
# BsmtFinSF2         0    0.000000
# BsmtUnfSF          0    0.000000
# RoofStyle          0    0.000000
# YearRemodAdd       0    0.000000
# YearBuilt          0    0.000000
# LandContour        0    0.000000
# MSSubClass         0    0.000000
# MSZoning           0    0.000000
# LotFrontage        0    0.000000
# LotArea            0    0.000000
# ...

# %%
#Let's look at Electrical
train['Electrical'].value_counts()
print(train.shape,test.shape)
# Out:
# (1458, 80) (1459, 79)

# %%
#The large majority of houses have Standard Circuit Breakers, so let's just fill the missing row with that
train['Electrical'] = train['Electrical'].fillna('SBrkr')
test['Electrical'] = test['Electrical'].fillna('SBrkr')
print(train.shape,test.shape)
# Out:
# (1458, 80) (1459, 79)

# %%
#Last call for missing data
train.isnull().any().sum()
#print(train.shape,test.shape)
# Out:
# 0

# %% [markdown]
# Woohoo, no more missing data on the training set!

# %%
#Let's check and see what missing data is left on our test set
pd.concat([test.isnull().sum().sort_values(ascending=False),(test.isnull().sum()*100/test.isnull().count()).sort_values(ascending=False)],axis=1,keys=['Total','Percentage'])
# Out:
#                Total  Percentage
# MSZoning           4     0.27416
# Functional         2     0.13708
# SaleType           1     0.06854
# Exterior1st        1     0.06854
# Exterior2nd        1     0.06854
# KitchenQual        1     0.06854
# SaleCondition      0     0.00000
# ExterCond          0     0.00000
# MasVnrType         0     0.00000
# MasVnrArea         0     0.00000
# ExterQual          0     0.00000
# BsmtQual           0     0.00000
# Foundation         0     0.00000
# RoofStyle          0     0.00000
# BsmtCond           0     0.00000
# BsmtExposure       0     0.00000
# BsmtFinType1       0     0.00000
# BsmtFinSF1         0     0.00000
# BsmtFinType2       0     0.00000
# BsmtFinSF2         0     0.00000
# RoofMatl           0     0.00000
# YearRemodAdd       0     0.00000
# TotalBsmtSF        0     0.00000
# LotConfig          0     0.00000
# MSSubClass         0     0.00000
# LotFrontage        0     0.00000
# LotArea            0     0.00000
# ...

# %%
#Let's look at MSZoning
test['MSZoning'].value_counts()
# Out:
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
# Name: MSZoning, dtype: int64

# %%
#Most houses have RL for MSZoning, so let's fill any missing values with that
test['MSZoning'] = test['MSZoning'].fillna('RL')

# %%
#Let's look at Functional
test['Functional'].value_counts()
# Out:
# Typ     1357
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64

# %%
#Most houses have Typ for Functional, so let's fill any missing values with that
test['Functional'] = test['Functional'].fillna('Typ')

# %%
#Let's look at Exterior1st
test['Exterior1st'].value_counts()
# Out:
# VinylSd    510
# MetalSd    230
# HdBoard    220
# Wd Sdng    205
# Plywood    113
# CemntBd     65
# BrkFace     37
# WdShing     30
# AsbShng     24
# Stucco      18
# BrkComm      4
# CBlock       1
# AsphShn      1
# Name: Exterior1st, dtype: int64

# %%
#Most houses have VinylSd, so let's fill any missing values with that
test['Exterior1st'] = test['Exterior1st'].fillna('VinylSd')

# %%
#Let's look at Exterior2nd
test['Exterior2nd'].value_counts()
# Out:
# VinylSd    510
# MetalSd    233
# HdBoard    199
# Wd Sdng    194
# Plywood    128
# CmentBd     66
# Wd Shng     43
# BrkFace     22
# Stucco      21
# AsbShng     18
# Brk Cmn     15
# ImStucc      5
# CBlock       2
# AsphShn      1
# Stone        1
# Name: Exterior2nd, dtype: int64

# %%
#Most houses have VinylSd, so let's fill any missing values with that
test['Exterior2nd'] = test['Exterior2nd'].fillna('VinylSd')

# %%
#Let's look at KitchenQual
test['KitchenQual'].value_counts()
# Out:
# TA    757
# Gd    565
# Ex    105
# Fa     31
# Name: KitchenQual, dtype: int64

# %%
#Most houses have TA, so let's fill any missing values with that
test['KitchenQual'] = test['KitchenQual'].fillna('TA')

# %%
#Let's look at KitchenQual
test['SaleType'].value_counts()
# Out:
# WD       1258
# New       117
# COD        44
# ConLD      17
# CWD         8
# ConLI       4
# Oth         4
# ConLw       3
# Con         3
# Name: SaleType, dtype: int64

# %%
#Most houses have WD, so let's fill any missing values with that
test['SaleType'] = test['SaleType'].fillna('WD')

# %%
#Last call for missing data
test.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# Alright! No missing data in the test set.

# %% [markdown]
# ### Categorical to Numerical

# %%
#We need to transform the variables with hierarchal categorical data into numerical data 
train['MSSubClass'] = train['MSSubClass'].apply(str)
train['OverallCond'] = train['OverallCond'].astype(str)
train['YrSold'] = train['YrSold'].astype(str)
train['MoSold'] = train['MoSold'].astype(str)
#Test set
test['MSSubClass'] = test['MSSubClass'].apply(str)
test['OverallCond'] = test['OverallCond'].astype(str)
test['YrSold'] = test['YrSold'].astype(str)
test['MoSold'] = test['MoSold'].astype(str)
print(train.shape,test.shape)
# Out:
# (1458, 80) (1459, 79)

# %%
#Let's now create dummy variables for the other categorical variables
train = pd.get_dummies(train)
test = pd.get_dummies(test)
print(train.shape,test.shape)
# Out:
# (1458, 338) (1459, 322)

# %%
#Let's create our target variable and drop SalePrice
target = train['SalePrice']
train.drop(['SalePrice'], axis=1, inplace=True)

#Now we need to make sure our sets are the same shape
test.drop(['MSSubClass_150'], axis=1, inplace=True)
test_columns = test.columns
train = train[test_columns]
print(train.shape,test.shape)
# Out:
# (1458, 321) (1459, 321)

# %% [markdown]
# # Modeling Time

# %%
#Create our target variable
#target = train['SalePrice']
#Let's drop SalesPrice now
#train.drop(['SalePrice'], axis=1, inplace=True)
#Also, lets save and drop ID 
#Id = train.Id
#train.drop(['Id'], axis=1, inplace=True)
test_Id = test.Id
test.drop(['Id'], axis=1, inplace=True)

# %%
#Let's just try a single variable model to test submitting to Kaggle
X = pd.DataFrame(train.OverallQual)
y = target
single_model = KNeighborsRegressor(n_neighbors=4)
single_model.fit(X,y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#           weights='uniform')

# %%
mse = mean_squared_error(target, single_model.predict(pd.DataFrame(train.OverallQual)))
print("RMSE: {}".format(np.sqrt(mse)))
# Out:
# RMSE: 0.2401967892020083

# %%
predictions = single_model.predict(pd.DataFrame(test.OverallQual))

# %%
#save results to csv to submit to kaggle (undo the log transformation)
outcome = pd.DataFrame({"ID":test_Id,"SalePrice":np.expm1(predictions)})
outcome.head()
# Out:
#      ID      SalePrice
# 0  1461  126596.560196
# 1  1462  174704.355147
# 2  1463  126596.560196
# 3  1464  174704.355147
# 4  1465  229491.638625

# %%
outcome.to_csv("simple_model_test.csv",index=False)

# %% [markdown]
# #### Our 1 variable model got us a 0.24174 on Kaggle, let's improve that
# ## Linear Regression Model

# %%
#Let's scale our data
scaler = StandardScaler()
scaler.fit(train)
scaled = scaler.transform(train)

# %%
#Let's split the training data into a training and test
X_train, X_test, y_train, y_test = train_test_split(scaled, target, test_size=.2)
#Let's run the Linear Regression
linear_regression_model = SGDRegressor(tol=.0001, eta0=.01)
linear_regression_model.fit(X_train, y_train)
train_predictions = linear_regression_model.predict(X_train)
test_predictions = linear_regression_model.predict(X_test)

train_mse = mean_squared_error(y_train, train_predictions)
test_mse = mean_squared_error(y_test, test_predictions)

print("Train RMSE: {}".format(np.sqrt(train_mse)))
print("Test RMSE: {}".format(np.sqrt(test_mse)))
# Out:
# Train RMSE: 1298.7689670074978
# Test RMSE: 195.75387291196378

# %% [markdown]
# Wow, the linear regression isn't looking too hot.

# %%
#Let's try running K-nearest neighbors
reg = KNeighborsRegressor()
#gridsearch = GridSearchCV(reg, {"n_neighbors": [1, 3, 5, 7, 9, 11], "weights": ['uniform', 'distance'], 
#                                'p': [1, 2, 3]}, scoring='neg_mean_squared_error')
gridsearch = GridSearchCV(reg, {"n_neighbors": [1, 3, 5, 7, 9, 11]})
gridsearch.fit(X_train, y_train)
train_predictions = gridsearch.predict(X_train)
test_predictions = gridsearch.predict(X_test)

train_mse = mean_squared_error(y_train, train_predictions)
test_mse = mean_squared_error(y_test, test_predictions)

print("Best Params: {}".format(gridsearch.best_params_))
print("Train RMSE: {}".format(np.sqrt(train_mse)))
print("Test RMSE: {}".format(np.sqrt(test_mse)))
# Out:
# Best Params: {'n_neighbors': 7}
# Train RMSE: 0.16946261442508348
# Test RMSE: 0.20180313716063422

# %%
KNN = KNeighborsRegressor(n_neighbors=7)
KNN.fit(train,target)
predictions = KNN.predict(test)

#save results to csv to submit to kaggle
knn_outcome = pd.DataFrame({"ID":test_Id,"SalePrice":np.expm1(predictions)})
knn_outcome.to_csv("KNN.csv",index=False)
knn_outcome.head()
# Out:
#      ID      SalePrice
# 0  1461  146215.596718
# 1  1462  202083.329359
# 2  1463  184333.419180
# 3  1464  200733.946374
# 4  1465  149699.072030

# %% [markdown]
# Alright! The K-Nearest Neighbors model scored 0.23705 on Kaggle, a little better than our 1 variable model.

# %%
#Let's try Lasso
lassy = Lasso(alpha=0.0005, max_iter=100, selection='random')

lassy.fit(X_train, y_train)
train_predictions = lassy.predict(X_train)
test_predictions = lassy.predict(X_test)

train_mse = mean_squared_error(y_train, train_predictions)
test_mse = mean_squared_error(y_test, test_predictions)

print("Train RMSE: {}".format(np.sqrt(train_mse)))
print("Test RMSE: {}".format(np.sqrt(test_mse)))
# Out:
# Train RMSE: 0.0853781889916256
# Test RMSE: 0.13703062344138325

# %% [markdown]
# Our lasso model did better than our K-Nearest Neighbors, but let's try another model.

# %%
#Let's try running an ElasticNetCV model
clf = ElasticNetCV(l1_ratio=[.1, .5, .7, .9, .95, .99, 1], alphas=[.001,.01,.1, 1, 10, 100])
clf.fit(X_train, y_train)
train_predictions = clf.predict(X_train)
test_predictions = clf.predict(X_test)

train_mse = mean_squared_error(y_train, train_predictions)
test_mse = mean_squared_error(y_test, test_predictions)

print("Train RMSE: {}".format(np.sqrt(train_mse)))
print("Test RMSE: {}".format(np.sqrt(test_mse)))
# Out:
# Train RMSE: 0.09876863677864178
# Test RMSE: 0.11974584641986427

# %%
clf.fit(train,target)
predictions = clf.predict(test)

#save results to csv to submit to kaggle
knn_outcome = pd.DataFrame({"ID":test_Id,"SalePrice":np.expm1(predictions)})
knn_outcome.to_csv("ElasticNetCV.csv",index=False)
knn_outcome.head()
# Out:
#      ID      SalePrice
# 0  1461  120500.572618
# 1  1462  152716.972761
# 2  1463  178886.183736
# 3  1464  202213.170702
# 4  1465  191825.934645

# %% [markdown]
# I fiddled around with the hyper parameters a little bit and found this to be the optimal set. I was able to move from 0.14928 to 0.12444 doing so.
